# %% [markdown]
# ## Turning images into numpy arrays

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Load and display the image
img = Image.open("numpy-images/panda.png")
plt.imshow(img)
plt.axis('off')  # Turn off axis
plt.show()

# %%
# Turn an image into numpy array
from matplotlib.image import imread
panda=imread("numpy-images/panda.png")
print(type(panda))
# Out:
# <class 'numpy.ndarray'>

# %%
panda
# Out:
# array([[[0.05490196, 0.10588235, 0.06666667],
#         [0.05490196, 0.10588235, 0.06666667],
#         [0.05490196, 0.10588235, 0.06666667],
#         ...,
#         [0.16470589, 0.12941177, 0.09411765],
#         [0.16470589, 0.12941177, 0.09411765],
#         [0.16470589, 0.12941177, 0.09411765]],
#
#        [[0.05490196, 0.10588235, 0.06666667],
#         [0.05490196, 0.10588235, 0.06666667],
#         [0.05490196, 0.10588235, 0.06666667],
#         ...,
#         [0.16470589, 0.12941177, 0.09411765],
#         [0.16470589, 0.12941177, 0.09411765],
#         [0.16470589, 0.12941177, 0.09411765]],
#
#        [[0.05490196, 0.10588235, 0.06666667],
#         [0.05490196, 0.10588235, 0.06666667],
#         [0.05490196, 0.10588235, 0.06666667],
#         ...,
#         [0.16470589, 0.12941177, 0.09411765],
#         [0.16470589, 0.12941177, 0.09411765],
#         [0.16470589, 0.12941177, 0.09411765]],
#
#        ...,
#
#        [[0.13333334, 0.07450981, 0.05490196],
#         [0.12156863, 0.0627451 , 0.04313726],
#         [0.10980392, 0.05098039, 0.03137255],
#         ...,
#         [0.02745098, 0.02745098, 0.03529412],
#         [0.02745098, 0.02745098, 0.03529412],
#         [0.02745098, 0.02745098, 0.03529412]],
#
#        [[0.13333334, 0.07450981, 0.05490196],
#         [0.12156863, 0.0627451 , 0.04313726],
#         [0.12156863, 0.0627451 , 0.04313726],
#         ...,
#         [0.02352941, 0.02352941, 0.03137255],
#         [0.02352941, 0.02352941, 0.03137255],
#         [0.02352941, 0.02352941, 0.03137255]],
#
#        [[0.13333334, 0.07450981, 0.05490196],
#         [0.12156863, 0.0627451 , 0.04313726],
#         [0.12156863, 0.0627451 , 0.04313726],
#         ...,
#         [0.02352941, 0.02352941, 0.03137255],
#         [0.02352941, 0.02352941, 0.03137255],
#         [0.02352941, 0.02352941, 0.03137255]]], dtype=float32)

# %%
panda.size, panda.shape, panda.ndim
# Out:
# (24465000, (2330, 3500, 3), 3)

# %%
panda[:100]
# Out:
# array([[[0.05490196, 0.10588235, 0.06666667],
#         [0.05490196, 0.10588235, 0.06666667],
#         [0.05490196, 0.10588235, 0.06666667],
#         ...,
#         [0.16470589, 0.12941177, 0.09411765],
#         [0.16470589, 0.12941177, 0.09411765],
#         [0.16470589, 0.12941177, 0.09411765]],
#
#        [[0.05490196, 0.10588235, 0.06666667],
#         [0.05490196, 0.10588235, 0.06666667],
#         [0.05490196, 0.10588235, 0.06666667],
#         ...,
#         [0.16470589, 0.12941177, 0.09411765],
#         [0.16470589, 0.12941177, 0.09411765],
#         [0.16470589, 0.12941177, 0.09411765]],
#
#        [[0.05490196, 0.10588235, 0.06666667],
#         [0.05490196, 0.10588235, 0.06666667],
#         [0.05490196, 0.10588235, 0.06666667],
#         ...,
#         [0.16470589, 0.12941177, 0.09411765],
#         [0.16470589, 0.12941177, 0.09411765],
#         [0.16470589, 0.12941177, 0.09411765]],
#
#        ...,
#
#        [[0.06666667, 0.12156863, 0.07058824],
#         [0.06666667, 0.12156863, 0.07058824],
#         [0.06666667, 0.12156863, 0.07058824],
#         ...,
#         [0.1882353 , 0.15686275, 0.11372549],
#         [0.1882353 , 0.15686275, 0.11372549],
#         [0.1882353 , 0.15686275, 0.11372549]],
#
#        [[0.06666667, 0.12156863, 0.07058824],
#         [0.06666667, 0.12156863, 0.07058824],
#         [0.06666667, 0.12156863, 0.07058824],
#         ...,
#         [0.1882353 , 0.15686275, 0.11372549],
#         [0.1882353 , 0.15686275, 0.11372549],
#         [0.1882353 , 0.15686275, 0.11372549]],
#
#        [[0.06666667, 0.12156863, 0.07058824],
#         [0.06666667, 0.12156863, 0.07058824],
#         [0.06666667, 0.12156863, 0.07058824],
#         ...,
#         [0.1882353 , 0.15686275, 0.11372549],
#         [0.1882353 , 0.15686275, 0.11372549],
#         [0.1882353 , 0.15686275, 0.11372549]]], dtype=float32)

# %%
img = Image.open("numpy-images/doll.webp")
plt.imshow(img)
plt.axis('off')  # Turn off axis
plt.show()

# %%
from matplotlib.image import imread
doll=imread("numpy-images/doll.webp")
print(type(doll))
# Out:
# <class 'numpy.ndarray'>

# %%
doll
# Out:
# array([[[110, 118, 125],
#         [108, 116, 122],
#         [105, 113, 120],
#         ...,
#         [250, 248, 235],
#         [250, 248, 235],
#         [250, 248, 235]],
#
#        [[118, 126, 133],
#         [117, 125, 131],
#         [115, 123, 129],
#         ...,
#         [250, 248, 235],
#         [250, 248, 235],
#         [250, 248, 235]],
#
#        [[131, 139, 145],
#         [130, 138, 144],
#         [128, 136, 142],
#         ...,
#         [250, 248, 235],
#         [250, 248, 235],
#         [250, 248, 235]],
#
#        ...,
#
#        [[239, 229, 218],
#         [240, 230, 220],
#         [240, 230, 220],
#         ...,
#         [248, 244, 238],
#         [248, 244, 238],
#         [248, 244, 238]],
#
#        [[240, 230, 220],
#         [240, 230, 220],
#         [239, 229, 218],
#         ...,
#         [248, 244, 238],
#         [248, 244, 238],
#         [248, 244, 238]],
#
#        [[240, 230, 220],
#         [240, 230, 220],
#         [239, 229, 218],
#         ...,
#         [248, 244, 238],
#         [248, 244, 238],
#         [248, 244, 238]]], dtype=uint8)
