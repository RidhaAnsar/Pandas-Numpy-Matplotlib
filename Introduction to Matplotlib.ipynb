# %% [markdown]
# ## Introduction to matplottlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot()
# Out:
# []

# %%
plt.plot();

# %%
plt.plot([1,2,3,4,5,6,7]);

# %%
x=[2,4,6,10]
y=[2,1,9,8]
plt.plot(x,y);

# %%
fig=plt.figure()
ax=fig.add_axes([1,1,1,1])
ax.plot(x,y)
plt.show()
