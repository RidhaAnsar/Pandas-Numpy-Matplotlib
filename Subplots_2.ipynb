# %% [markdown]
# <a href="https://colab.research.google.com/github/RidhaAnsar/Pandas-Numpy-Matplotlib/blob/main/Subplots_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.random.rand(1000)
fig, ax=plt.subplots(nrows=2, ncols=2, figsize=(10,5))
ax[0,0].plot(x,x/2);
ax[0,1].scatter(np.random.random(10), np.random.random(10));
Categories=['a','b','c']
values=[10,15,20]
ax[1,0].bar(Categories, values);
ax[1,1].barh(Categories, values);
